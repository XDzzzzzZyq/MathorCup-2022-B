# %% [markdown]
# # 语音业务

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Clean Up

# %%
data_raw = pd.read_excel("附件1语音业务用户满意度数据.xlsx").set_index("用户id")

# %%
data = data_raw.copy()
data
# Out:
#       语音通话整体满意度  网络覆盖与信号强度  语音通话清晰度  语音通话稳定性  是否遇到过网络问题  居民小区  办公室  高校  商业街  \
# 用户id
# 1            10          6        6        6          1    -1    2  -1   -1
# 2             2          1        1        1          1     1    2  -1    4
# 3            10          7        7        7          1    -1   -1  -1   -1
# 4             6          7        7        6          1     1    2  -1   -1
# 5             5          5        4        3          1    -1    2  -1   -1
# ...         ...        ...      ...      ...        ...   ...  ...  ..  ...
# 5429         10         10       10        8          1    -1    2  -1   -1
# 5430         10         10       10       10          1     1    2  -1   -1
# 5431          6          5        7        4          1    -1   -1  -1    4
# 5432          9          9       10        9          1    -1   -1  -1   -1
# 5433         10         10       10       10          1     1    2  -1   -1
#
#       地铁  ...  前3月ARPU  前3月MOU  外省流量占比 GPRS总流量（KB）  GPRS-国内漫游-流量（KB）  \
# 用户id      ...
# 1     -1  ...      0.0     480     1.0     8450801           8450801
# 2     -1  ...      0.0     480     1.0    17425910          17425910
# 3     -1  ...      0.0     413     1.0     6215849           6215849
# 4     -1  ...      0.0     301     1.0     5370710           5370710
# 5      5  ...      0.0    1193     1.0     3857521           3857521
# ...   ..  ...      ...     ...     ...         ...               ...
# 5429  -1  ...      0.0     320     0.0    16654303                 0
# 5430  -1  ...      0.0     147     0.0      627901                 0
# 5431  -1  ...      0.0     150     0.0     6816663                 0
# 5432   5  ...      0.0      82     0.0     1841891                 0
# 5433   5  ...      0.0     258     0.0         810                 0
#
#       是否5G网络客户  是否实名登记用户  客户星级标识  当月欠费金额  前第3个月欠费金额
# 用户id
# 1            是         否      银卡     0.0       0.00
# 2            是         是      银卡     0.0       0.00
# 3            否         否      三星     0.0       3.76
# 4            是         否      三星     0.0       0.00
# 5            否         否      银卡     0.0       0.00
# ...        ...       ...     ...     ...        ...
# 5429         否         否      二星     0.0       0.00
# 5430         是         否      三星     0.0       0.00
# 5431         否         否      银卡     0.0       0.00
# 5432         否         否      三星     0.0       0.00
# 5433         否         否      三星     0.0       0.00
#
# [5433 rows x 54 columns]

# %%
# Binary Conversion

bool_1 = ["居民小区","办公室","高校","商业街","地铁"]
bool_2 = ["手机没有信号","有信号无法拨通","通话过程中突然中断","通话中有杂音、听不清、断断续续","串线","通话过程中一方听不见"]
bool_3 = ["脱网次数","mos质差次数","未接通掉话次数"]

def binary(df, tar):
    df[tar] = df[tar].apply(pd.to_numeric, errors='coerce')<=0
    return df

data = binary(data, bool_1)
data = binary(data, bool_2)
data = binary(data, bool_3)

# %%
# Class Conversion

class_1 = [r"4\5G用户", "是否5G网络客户", "语音方式", "终端品牌"]
class_2 = ["是否实名登记用户","客户星级标识"]

def classif(df, tar):
    for cls in tar:
        df[cls],_ = pd.factorize(df[cls])
        
    return df

data = classif(data, class_1)
data = classif(data, class_2)

# %%
data.head()
# Out:
#       语音通话整体满意度  网络覆盖与信号强度  语音通话清晰度  语音通话稳定性  是否遇到过网络问题   居民小区    办公室    高校  \
# 用户id
# 1            10          6        6        6          1   True  False  True
# 2             2          1        1        1          1  False  False  True
# 3            10          7        7        7          1   True   True  True
# 4             6          7        7        6          1  False  False  True
# 5             5          5        4        3          1   True  False  True
#
#         商业街     地铁  ...  前3月ARPU  前3月MOU  外省流量占比 GPRS总流量（KB）  \
# 用户id                ...
# 1      True   True  ...      0.0     480     1.0     8450801
# 2     False   True  ...      0.0     480     1.0    17425910
# 3      True   True  ...      0.0     413     1.0     6215849
# 4      True   True  ...      0.0     301     1.0     5370710
# 5      True  False  ...      0.0    1193     1.0     3857521
#
#       GPRS-国内漫游-流量（KB）  是否5G网络客户  是否实名登记用户  客户星级标识  当月欠费金额  前第3个月欠费金额
# 用户id
# 1              8450801         0         0       0     0.0       0.00
# 2             17425910         0         1       0     0.0       0.00
# 3              6215849         1         0       1     0.0       3.76
# 4              5370710         0         0       1     0.0       0.00
# 5              3857521         1         0       0     0.0       0.00
#
# [5 rows x 54 columns]

# %%
int_score = ["语音通话整体满意度","网络覆盖与信号强度","语音通话清晰度","语音通话稳定性"]

data[int_score] = data[int_score].apply(pd.to_numeric, errors='coerce')

# %%
score = data[int_score]
score = score.values.T
score
# Out:
# array([[10,  2, 10, ...,  6,  9, 10],
#        [ 6,  1,  7, ...,  5,  9, 10],
#        [ 6,  1,  7, ...,  7, 10, 10],
#        [ 6,  1,  7, ...,  4,  9, 10]], dtype=int64)

# %% [markdown]
# ## 打分线性回归

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(score[1:].T, score[0])
# Out:
# LinearRegression()

# %% [markdown]
# ### 拟合结果

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(score[0, :200])

score_pred = model.predict(score[1:].T)
plt.plot(score_pred[:200])

plt.subplots_adjust(left=0, right=2, bottom = 0, top= 1)

print(model.coef_)
print(model.intercept_)
# Out:
# [0.29897125 0.44369613 0.19968409]
# 0.6732004276680339

# %% [markdown]
# ## 决策树打分逐项分析

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score
sig_regr = DecisionTreeRegressor(max_depth=20)

# %% [markdown]
# ### 信号强度分析

# %%
signal = data[bool_1+bool_2+class_1].values
signal
# Out:
# array([[True, False, True, ..., 0, 0, 0],
#        [False, False, True, ..., 0, 0, 1],
#        [True, True, True, ..., 1, 1, 1],
#        ...,
#        [True, True, True, ..., 1, 1, 1],
#        [True, True, True, ..., 1, 2, 4],
#        [False, False, True, ..., 1, 1, 0]], dtype=object)

# %%
sig_regr.fit(signal, score[1])
# Out:
# DecisionTreeRegressor(max_depth=20)

# %%
signal_scr_pred = np.round(sig_regr.predict(signal))

plt.plot(score[1, :200])
plt.plot(signal_scr_pred[:200])

plt.subplots_adjust(left=0, right=2, bottom = 0, top= 1)

print("accr:",accuracy_score(score[1], signal_scr_pred))
# Out:
# accr: 0.5466593042517945

# %% [markdown]
# ### 清晰度分析

# %%
clar_regr = DecisionTreeRegressor(max_depth=20)

clarity = data[bool_1+bool_2+bool_3+class_1].values
clarity
# Out:
# array([[True, False, True, ..., 0, 0, 0],
#        [False, False, True, ..., 0, 0, 1],
#        [True, True, True, ..., 1, 1, 1],
#        ...,
#        [True, True, True, ..., 1, 1, 1],
#        [True, True, True, ..., 1, 2, 4],
#        [False, False, True, ..., 1, 1, 0]], dtype=object)

# %%
clar_regr.fit(clarity, score[2])
# Out:
# DecisionTreeRegressor(max_depth=20)

# %%
clar_scr_pred = np.round(clar_regr.predict(clarity))

plt.plot(score[2, :200])
plt.plot(clar_scr_pred[:200])

plt.subplots_adjust(left=0, right=2, bottom = 0, top= 1)

print("accr:",accuracy_score(score[2], clar_scr_pred))
# Out:
# accr: 0.7710288974783729

# %% [markdown]
# ### 稳定性分析

# %%
stab_regr = DecisionTreeRegressor(max_depth=20)

stability = data[bool_1+bool_2+bool_3+class_1].values
stability
# Out:
# array([[True, False, True, ..., 0, 0, 0],
#        [False, False, True, ..., 0, 0, 1],
#        [True, True, True, ..., 1, 1, 1],
#        ...,
#        [True, True, True, ..., 1, 1, 1],
#        [True, True, True, ..., 1, 2, 4],
#        [False, False, True, ..., 1, 1, 0]], dtype=object)

# %%
stab_regr.fit(stability, score[3])
# Out:
# DecisionTreeRegressor(max_depth=20)

# %%
stab_scr_pred = np.round(stab_regr.predict(stability))

plt.plot(score[2, :200])
plt.plot(stab_scr_pred[:200])

plt.subplots_adjust(left=0, right=2, bottom = 0, top= 1)

print("accr:",accuracy_score(score[2], stab_scr_pred))
# Out:
# accr: 0.5998527517025585

# %% [markdown]
# ## 整体估计

# %%
pred_sub = np.array([signal_scr_pred, clar_scr_pred, stab_scr_pred]).T
pred = model.predict(pred_sub)

plt.plot(score[0, :200])
plt.plot(np.round(pred[:200]))

plt.subplots_adjust(left=0, right=2, bottom = 0, top= 1)

print("accr:",accuracy_score(score[0], np.round(pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 9
#       5 plt.plot(pred[:200])
#       7 plt.subplots_adjust(left=0, right=2, bottom = 0, top= 1)
# ----> 9 print("accr:",accuracy_score(score[0], pred))
#
# File D:\ProgramData\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py:192, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 validate_parameter_constraints(
#     188     parameter_constraints, params, caller_name=func.__qualname__
#     189 )
#     191 try:
# --> 192     return func(*args, **kwargs)
#     193 except InvalidParameterError as e:
#     194     # When the function is just a wrapper around an estimator, we allow
#     195     # the function to delegate validation to the estimator, but we replace
#     196     # the name of the estimator by the name of the function in the error
#     197     # message to avoid confusion.
#     198     msg = re.sub(
#     199         r"parameter of \w+ must be",
#     200         f"parameter of {func.__qualname__} must be",
#     201         str(e),
#     202     )
#
# File D:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:221, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     155 """Accuracy classification score.
#     156
#     157 In multilabel classification, this function computes subset accuracy:
#    (...)
#     217 0.5
#     218 """
#     220 # Compute accuracy for each possible representation
# --> 221 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     222 check_consistent_length(y_true, y_pred, sample_weight)
#     223 if y_type.startswith("multilabel"):
#
# File D:\ProgramData\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:95, in _check_targets(y_true, y_pred)
#      92     y_type = {"multiclass"}
#      94 if len(y_type) > 1:
# ---> 95     raise ValueError(
#      96         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      97             type_true, type_pred
#      98         )
#      99     )
#     101 # We can't have more than one value on y_type => The set is no more needed
#     102 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
